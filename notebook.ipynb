# %% [markdown]
# <a href="https://colab.research.google.com/github/abhaysinghhh/Cara_Prices_Analysis/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Problem Statement
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
#     - Which variables are significant in predicting the price of a car
#     - How well those variables describe the price of a car
#
# Based on various market surveys, the consulting firm has gathered a large dataset of different types of cars across the Americal market.

# %% [markdown]
# ### Business Goal
#
# Model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# ## Import Python Libraries
# Setting up the Environment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn import metrics
# !pip install word2number
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting word2number
#   Downloading word2number-1.1.zip (9.7 kB)
# Building wheels for collected packages: word2number
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5582 sha256=eacf162cdd54ee17d3a8ad41656ce75378830469a76cff938c5e08f00bdbd878
#   Stored in directory: /root/.cache/pip/wheels/cb/f3/5a/d88198fdeb46781ddd7e7f2653061af83e7adb2a076d8886d6
# Successfully built word2number
# Installing collected packages: word2number
# Successfully installed word2number-1.1

# %%
sns.set_style('darkgrid')
pd.set_option('display.max_columns', 30)
#np.random.seed(4)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Understanding the Data

# %%
df = pd.read_csv("Kaggle_Dataset.csv")
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
#    carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# 0       48.8        2548       dohc           four         130       mpfi
# 1       48.8        2548       dohc           four         130       mpfi
# 2       52.4        2823       ohcv            six         152       mpfi
# 3       54.3        2337        ohc           four         109       mpfi
# 4       54.3        2824        ohc           five         136       mpfi
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0

# %%
df.columns #given features that affect price
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.shape
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %% [markdown]
# ## Data Preprocessing

# %%
cars = df.copy()

# %%
brand = cars['CarName'].apply(lambda x : x.split(' ')[0]) #split company name from carname
cars.insert(3,"CompanyName", brand)

# %%
cars.drop(["CarName"], axis = 1, inplace = True)

# %%
cars.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %% [markdown]
# ###### Spelling errors in 'CompanyName' column

# %%
cars.CompanyName = cars.CompanyName.str.lower()

#replace with correct spellings
cars.CompanyName.replace('maxda','mazda', inplace = True)
cars.CompanyName.replace('porcshce','porsche', inplace = True)
cars.CompanyName.replace('toyouta','toyota', inplace = True)
cars.CompanyName.replace('vokswagen','volkswagen', inplace = True)
cars.CompanyName.replace('vw','volkswagen', inplace = True)

cars.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
cars.loc[cars.duplicated()]
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, CompanyName, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []

# %%
#No Duplicated values found
cars.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %% [markdown]
# Checking for Null Values

# %%
cars.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CompanyName         0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
cars[['doornumber','cylindernumber']].head()
# Out:
#   doornumber cylindernumber
# 0        two           four
# 1        two           four
# 2        two            six
# 3       four           four
# 4       four           five

# %%
from word2number import w2n
#convert number words to numeric digits

for i in range(len(cars.doornumber)):
    cars.doornumber[i] = w2n.word_to_num(cars.doornumber[i])
    cars.cylindernumber[i] = w2n.word_to_num(cars.cylindernumber[i])
cars[['doornumber','cylindernumber']].head()
# Out:
# <ipython-input-36-c305a9c597ee>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars.doornumber[i] = w2n.word_to_num(cars.doornumber[i])
# <ipython-input-36-c305a9c597ee>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars.cylindernumber[i] = w2n.word_to_num(cars.cylindernumber[i])
#   doornumber cylindernumber
# 0          2              4
# 1          2              4
# 2          2              6
# 3          4              4
# 4          4              5

# %% [markdown]
# ## Understanding and Visualising Data

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
sns.kdeplot(cars.price, fill = 'true')
plt.subplot(1,2,2)
sns.boxplot(cars.price)
plt.show()

# %% [markdown]
# Inference :
#
# 1. The plot is right-skewed, meaning that the most prices in the dataset are low(Below 15,000).
# 2. The data points are far spread out from the mean, which indicates a high variance in the car prices.(85% of the prices are below 18,500, whereas the remaining 15% are between 18,500 and 45,400.)

# %%
cars.price.describe()
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
#Feature Generation
cars['fueleconomy'] = (0.55 * cars['citympg']) + (0.45 * cars['highwaympg'])

# %%
cars1 = cars[['price', 'fueltype', 'aspiration','carbody', 'drivewheel','wheelbase','fueleconomy',
                  'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 'carlength','carwidth']]

plt.figure(figsize = (15,15))
sns.heatmap(cars1.corr(), annot = True, cmap = "PiYG")
plt.show()

# %% [markdown]
# ### Visualising Categorical data

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CompanyName       205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
#  26  fueleconomy       205 non-null    float64
# dtypes: float64(9), int64(8), object(10)
# memory usage: 43.4+ KB

# %%
plt.figure(figsize=(22,5))
plt.subplot(1,2,1)

sns.countplot(cars.CompanyName).set_title('Companies')
plt.xticks(rotation = 90)
plt.subplot(1,2,2)
kd = pd.DataFrame(cars.groupby(['CompanyName'])['price'].mean().sort_values(ascending = False))
kd = kd.reset_index()
sns.barplot(x = kd.CompanyName, y = kd.price).set_title("Average Price Vs Company")
plt.xticks(rotation = 90)
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
#  Inference:
#
#  1. `Toyota` makes the most buyed cars with `Average Price` around `10000`.
#  2. `Jaguar`, `Buick`, and `Porsche` seems to have highest average price.

# %%
plt.figure(figsize=(24,15))
plt.subplot(2,4,1)
sns.countplot(cars.fueltype).set_title('Fueltypes')

plt.subplot(2,4,2)
sns.countplot(cars.enginetype).set_title('Enginetype')

plt.subplot(2,4,3)
sns.countplot(cars.carbody).set_title('Cartype')
plt.xticks(rotation = 90)

plt.subplot(2,4,4)
sns.countplot(cars.doornumber).set_title('Doornumber')


plt.subplot(2,4,5)
sns.boxplot(x = cars.fueltype, y = cars.price).set_title('Fueltype vs Price')

plt.subplot(2,4,6)
kd = pd.DataFrame(cars.groupby(['enginetype'])['price'].mean())
kd = pd.DataFrame({'x': cars['enginetype'].unique(), 'price': kd['price']})
sns.barplot(x = kd['x'], y = kd['price']).set_title('Enginetype vs Average Price')
plt.xlabel('enginetype')
plt.ylabel('Average Price')

plt.subplot(2,4,7)
kd = pd.DataFrame(cars.groupby(['carbody'])['price'].mean())
kd = pd.DataFrame({'x': cars['carbody'].unique(), 'price': kd['price']})
sns.barplot(x = kd['x'], y = kd['price']).set_title('Cartype vs Average Price')
plt.xlabel('carbody')
plt.ylabel('Average Price')
plt.xticks(rotation = 90)


plt.subplot(2,4,8)
sns.boxplot(x = cars.doornumber, y = cars.price).set_title('Door Number vs Price')
plt.tight_layout()
plt.show()

# %% [markdown]
#  Inference:
#
# 1. Number of `gas` fueled cars are more than `diesel` fueled.
# 2. Median price of `gas` fueled cars is lesser than `diesel` cars.
# 3. `ohc` is the most preferred engine type with average price around 15000.
# 4. `sedan` is the top car type prefered. `convertible` and `hatchback` cars have higher average price
# 5. Cars with 4 `doors` were preferred over 2 doors.

# %%
plt.figure(figsize = (20,13))

plt.subplot(2,3,1)
sns.countplot(cars.symboling).set_title('Symboling')

plt.subplot(2,3,2)
sns.countplot(cars.aspiration).set_title('Aspiration')

plt.subplot(2,3,3)
sns.countplot(cars.drivewheel).set_title('Drivewheel')

plt.subplot(2,3,4)
sns.boxplot(x = cars.symboling, y = cars.price).set_title('Symboling vs Price')

plt.subplot(2,3,5)
sns.boxplot(x = cars.aspiration, y = cars.price).set_title('Aspiration vs Price')

plt.subplot(2,3,6)
sns.boxplot(x = cars.drivewheel, y = cars.price).set_title('Drivewheel vs Price')
plt.tight_layout()
plt.show()

# %% [markdown]
# Inference:
#
# 1. Mostly sold cars have `symboling` values between `0` and `1`.
# 2. Cars with lower symboling values have higher price.
# 3. Aspiration with `turbo` have higher interquartile range of price than `std`
# 4. Most high range cars seems to prefer `rwd`(rear-wheel-drive) drivewheel.

# %%
plt.figure(figsize = (15,10))
plt.subplot(2,2,1)
sns.countplot(cars.fuelsystem).set_title('Fuelsystem')

plt.subplot(2,2,3)
sns.boxplot(x = 'fuelsystem', y = 'price', data = cars).set_title('Fuelsystem vs Price')

plt.subplot(2,2,2)
sns.countplot(cars.enginelocation).set_title('Engine Location')

plt.subplot(2,2,4)
sns.boxplot(x = cars.enginelocation, y = cars.price).set_title('Engine Location vs Price')
plt.tight_layout()
plt.show()

# %% [markdown]
# Inference :
#
# 1. `mpfi` and `2bbl` are most common type of fuel systems. `mpfi` and `idi` having the highest price range. But there are few data for other categories to derive any meaningful inference.
# 2. Most cars have enginelocation as `front`. Very few datapoints for further infeence to be made.

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CompanyName       205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
#  26  fueleconomy       205 non-null    float64
# dtypes: float64(9), int64(8), object(10)
# memory usage: 43.4+ KB

# %% [markdown]
# ### Visualising Numeric Data

# %%
def pp(x,y,z):
    sns.pairplot(cars, x_vars=[x,y,z], y_vars='price',size=4, aspect=1, kind='scatter', hue = 'drivewheel')
    plt.show()

pp('enginesize', 'boreratio', 'stroke')
pp('compressionratio', 'horsepower', 'peakrpm')
pp('wheelbase', 'citympg', 'highwaympg')
plt.tight_layout()

# %% [markdown]
# Inference:
# 1. `enginesize`, `boreratio`, `horsepower`, `wheelbase` - have a significant positive correlation with price.
# 2. `citympg`, `highwaympg` - have a significant negative correlation with price.

# %%
def scatter(x,fig):
    plt.subplot(2,2,fig)
    sns.scatterplot(cars[x],cars['price'], hue = cars['enginetype'])
    plt.title(x+' vs Price')
    plt.ylabel('Price')
    plt.xlabel(x)

plt.figure(figsize=(20,12))

scatter('carlength', 1)
scatter('carwidth', 2)
scatter('carheight', 3)
scatter('curbweight', 4)
plt.tight_layout()
plt.show()

# %% [markdown]
#  Inference :
#
# 1. `carwidth`, `carlength` and `curbweight` seems to have a poitive correlation with `price`.
# 2. `carheight` doesn't show any significant trend with price.

# %%
plt.figure(figsize = (15,6))
plt.subplot(1,2,1)
sns.scatterplot(x = cars.fueleconomy, y = cars.price, hue = cars.horsepower).set_title('Fuel Economy vs Price')

plt.subplot(1,2,2)
sns.scatterplot(x = cars.enginesize, y = cars.price, hue = cars.horsepower).set_title('Enginesize vs Price')
plt.show()

# %% [markdown]
#  Inference :
#
# 1. `fueleconomy` has an obvious `negative correlation` with price and is significant.
# 2. Cars with more `horsepower` have higher `price` and low `fueleconomy`.
# 3. `enginesize` is highly correlated with `price`

# %%
plt.figure(figsize = (35,35))
cars1 = cars[['price', 'fueltype', 'aspiration','carbody', 'drivewheel','wheelbase','fueleconomy',
                  'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 'carlength','carwidth']]
sns.pairplot(cars1, diag_kind = 'kde', palette = "Set2")
plt.show()

# %% [markdown]
# # Building Machine Learning Models

# %%
cars.head()
# Out:
#    car_ID  symboling  CompanyName fueltype aspiration doornumber      carbody  \
# 0       1          3  alfa-romero      gas        std          2  convertible
# 1       2          3  alfa-romero      gas        std          2  convertible
# 2       3          1  alfa-romero      gas        std          2    hatchback
# 3       4          2         audi      gas        std          4        sedan
# 4       5          2         audi      gas        std          4        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
# 1        rwd          front       88.6      168.8      64.1       48.8
# 2        rwd          front       94.5      171.2      65.5       52.4
# 3        fwd          front       99.8      176.6      66.2       54.3
# 4        4wd          front       99.4      176.6      66.4       54.3
#
#    curbweight enginetype cylindernumber  enginesize fuelsystem  boreratio  \
# 0        2548       dohc              4         130       mpfi       3.47
# 1        2548       dohc              4         130       mpfi       3.47
# 2        2823       ohcv              6         152       mpfi       2.68
# 3        2337        ohc              4         109       mpfi       3.19
# 4        2824        ohc              5         136       mpfi       3.19
#
#    stroke  compressionratio  horsepower  peakrpm  citympg  highwaympg  \
# 0    2.68               9.0         111     5000       21          27
# 1    2.68               9.0         111     5000       21          27
# 2    3.47               9.0         154     5000       19          26
# 3    3.40              10.0         102     5500       24          30
# 4    3.40               8.0         115     5500       18          22
#
#      price  fueleconomy
# 0  13495.0        23.70
# 1  16500.0        23.70
# 2  16500.0        22.15
# 3  13950.0        26.70
# 4  17450.0        19.80

# %% [markdown]
# Convert Categorical Attributes to Numerical features by taking dummy variables

# %%
cars2 = cars.copy()
Y = cars.price
#cars2.drop(['car_ID','price'], axis = 'columns', inplace = True)
cars2 = pd.get_dummies(cars2)
cars2.drop(['car_ID','price'], axis = 'columns', inplace = True)
cars2.shape
# Out:
# (205, 75)

# %% [markdown]
# Using StandardScaler to remove the mean and scale each feature/variable to unit variance

# %%
slr = StandardScaler()
X_scaled = slr.fit_transform(cars2)

# %%
X_scaled
# Out:
# array([[ 1.74347043, -1.6907718 , -0.42652147, ...,  1.08666971,
#         -0.21428571, -0.070014  ],
#        [ 1.74347043, -1.6907718 , -0.42652147, ...,  1.08666971,
#         -0.21428571, -0.070014  ],
#        [ 0.133509  , -0.70859588, -0.23151305, ...,  1.08666971,
#         -0.21428571, -0.070014  ],
#        ...,
#        [-1.47645244,  1.72187336,  1.19854871, ...,  1.08666971,
#         -0.21428571, -0.070014  ],
#        [-1.47645244,  1.72187336,  1.19854871, ..., -0.92024282,
#         -0.21428571, -0.070014  ],
#        [-1.47645244,  1.72187336,  1.19854871, ...,  1.08666971,
#         -0.21428571, -0.070014  ]])

# %% [markdown]
# Dimensionality Reduction using Principal Component Analysis(PCA)

# %%
pca = PCA(0.95) #retaining 95% of information
cars_pca = pca.fit_transform(X_scaled)
cars_pca.shape
# Out:
# (205, 35)

# %% [markdown]
# Splitting dataset into training and test sets

# %%
np.random.seed(9)
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled,Y,test_size = 0.3)
#X_train, X_test, Y_train, Y_test = train_test_split(cars_pca,Y,test_size = 0.3, random_state= 9)

# %%
def print_metrics(y_test,y_pred):
  print('Mean Absolute Error:', round(metrics.mean_absolute_error(y_test, y_pred),2))
  print('Mean Squared Error:', round(metrics.mean_squared_error(y_test, y_pred),2))
  print('Root Mean Squared Error:', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),2))
  print('Mean Absolute Percentage Error:', round(metrics.mean_absolute_percentage_error(y_test, y_pred),2))
  print('R2 score:', round(metrics.r2_score(y_pred,y_test),2))

# %% [markdown]
# ### Since the target variable(`price`) is continuos which implies that regression will be the best suited technique for making prediction.
# We built 5 different regression models to compare the accuracies and chose one with best performance. These models include sklearn's, `LinearRegression()`, `DecisionTreeRegressor()`,`RandomForestRegressor()`, and XGBoost's(Extreme Gradient Boost) `XGBRegressor`. We also built a `Deep Neural Network` with 2 hidden layers and linear activation function.

# %% [markdown]
# ### Model 1: Multiple Linear Regression
#   - It is a statistical technique that uses several explanatory variables to predict the outcome of a response variable.
#   - In this section we use sklearn's `LinearRegression()` method to build model and predict the target variable.

# %%
lr = LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
print("Goodness of fit: " + str(round((lr.score(X_train,Y_train)*100),2)) + "%")
y_pred1 = lr.predict(X_test)
print("Model Score: "+ str(round(lr.score(X_test,Y_test)*100,2)) + "%")
# Out:
# Goodness of fit: 96.78%
# Model Score: 92.47%

# %%
print_metrics(Y_test,y_pred1)
# Out:
# Mean Absolute Error: 1645.5
# Mean Squared Error: 4617851.71
# Root Mean Squared Error: 2148.92
# Mean Absolute Percentage Error: 0.14
# R2 score: 0.94

# %%
plt.scatter(X_test[:,11], Y_test, color = 'red')
plt.scatter(X_test[:,11], y_pred1, color = 'green')
plt.show()

# %% [markdown]
# ### Model 2: Decision Tree Regression

# %%
#regressor = DecisionTreeRegressor(random_state=10, max_depth=4)
regressor = DecisionTreeRegressor( max_depth=4)

regressor.fit(X_train, Y_train)
y_pred2 = regressor.predict(X_test)
print("Goodness of fit: " + str(round((regressor.score(X_train,Y_train)*100),2)) + "%")
print("Model Score: "+ str(round(regressor.score(X_test,Y_test)*100,2)) + "%")
# Out:
# Goodness of fit: 95.24%
# Model Score: 87.99%

# %%
print_metrics(Y_test,y_pred2)
# Out:
# Mean Absolute Error: 1841.53
# Mean Squared Error: 7362708.29
# Root Mean Squared Error: 2713.43
# Mean Absolute Percentage Error: 0.14
# R2 score: 0.91

# %%
plt.scatter(X_test[:,10], Y_test, color = 'red')
plt.scatter(X_test[:,10], y_pred2, color = 'green')
plt.show()

# %% [markdown]
# ### Model 3. Random Forest Regression

# %%
#regressor = RandomForestRegressor(random_state=9)
regressor = RandomForestRegressor()
regressor.fit(X_train, Y_train)
y_pred3 = regressor.predict(X_test)

print("Goodness of fit: " + str(round((regressor.score(X_train,Y_train)*100),2)) + "%")
print("Model Score: "+ str(round(regressor.score(X_test,Y_test)*100,2)) + "%")
# Out:
# Goodness of fit: 98.71%
# Model Score: 92.86%

# %%
print_metrics(Y_test,y_pred3)
# Out:
# Mean Absolute Error: 1356.2
# Mean Squared Error: 4374366.01
# Root Mean Squared Error: 2091.5
# Mean Absolute Percentage Error: 0.11
# R2 score: 0.94

# %%
plt.scatter(X_test[:,12], Y_test, color = 'red')
plt.scatter(X_test[:,12], y_pred3, color = 'green')
plt.show()

# %% [markdown]
# ### Model 4. XGBRegressor

# %%
regressor = XGBRegressor()
regressor.fit(X_train, Y_train)
y_pred4 = regressor.predict(X_test)

print("Goodness of fit: " + str(round((regressor.score(X_train,Y_train)*100),2)) + "%")
print("Model Score: "+ str(round(regressor.score(X_test,Y_test)*100,2)) + "%")
# Out:
# [09:11:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Goodness of fit: 99.24%
# Model Score: 92.37%

# %%
print_metrics(Y_test,y_pred4)
# Out:
# Mean Absolute Error: 1346.64
# Mean Squared Error: 4680061.94
# Root Mean Squared Error: 2163.35
# Mean Absolute Percentage Error: 0.1
# R2 score: 0.94

# %%
plt.scatter(X_test[:,16], Y_test, color = 'red')
plt.scatter(X_test[:,16], y_pred4, color = 'green')
plt.show()

# %% [markdown]
# ### Model 5: Neural Network Based Regression

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# %%
NNmodel = Sequential()

# The Input Layer :
NNmodel.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NNmodel.add(Dense(256, kernel_initializer='normal',activation='relu'))
NNmodel.add(Dense(256, kernel_initializer='normal',activation='relu'))
#NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NNmodel.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NNmodel.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NNmodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               9728
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dense_3 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 108,801
# Trainable params: 108,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
NNmodel.fit(X_train, Y_train, epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# Epoch 1/500
# 1/4 [======>.......................] - ETA: 2s - loss: 15714.0771 - mean_absolute_error: 15714.0771
# Epoch 1: val_loss improved from inf to 13223.75000, saving model to Weights-001--13223.75000.hdf5
# 4/4 [==============================] - 1s 79ms/step - loss: 13636.0156 - mean_absolute_error: 13636.0156 - val_loss: 13223.7500 - val_mean_absolute_error: 13223.7500
# Epoch 2/500
# 1/4 [======>.......................] - ETA: 0s - loss: 15346.4170 - mean_absolute_error: 15346.4170
# Epoch 2: val_loss improved from 13223.75000 to 13222.65918, saving model to Weights-002--13222.65918.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 13635.2471 - mean_absolute_error: 13635.2471 - val_loss: 13222.6592 - val_mean_absolute_error: 13222.6592
# Epoch 3/500
# 1/4 [======>.......................] - ETA: 0s - loss: 12839.4805 - mean_absolute_error: 12839.4805
# Epoch 3: val_loss improved from 13222.65918 to 13220.56641, saving model to Weights-003--13220.56641.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 13633.7646 - mean_absolute_error: 13633.7646 - val_loss: 13220.5664 - val_mean_absolute_error: 13220.5664
# Epoch 4/500
# 1/4 [======>.......................] - ETA: 0s - loss: 13785.7891 - mean_absolute_error: 13785.7891
# Epoch 4: val_loss improved from 13220.56641 to 13216.73633, saving model to Weights-004--13216.73633.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 13630.8154 - mean_absolute_error: 13630.8154 - val_loss: 13216.7363 - val_mean_absolute_error: 13216.7363
# Epoch 5/500
# 1/4 [======>.......................] - ETA: 0s - loss: 14578.7539 - mean_absolute_error: 14578.7539
# Epoch 5: val_loss improved from 13216.73633 to 13210.17969, saving model to Weights-005--13210.17969.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 13625.3242 - mean_absolute_error: 13625.3242 - val_loss: 13210.1797 - val_mean_absolute_error: 13210.1797
# Epoch 6/500
# 1/4 [======>.......................] - ETA: 0s - loss: 12193.5801 - mean_absolute_error: 12193.5801
# Epoch 6: val_loss improved from 13210.17969 to 13199.44629, saving model to Weights-006--13199.44629.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 13615.5518 - mean_absolute_error: 13615.5518 - val_loss: 13199.4463 - val_mean_absolute_error: 13199.4463
# Epoch 7/500
# 1/4 [======>.......................] - ETA: 0s - loss: 13517.9805 - mean_absolute_error: 13517.9805
# Epoch 7: val_loss improved from 13199.44629 to 13182.35645, saving model to Weights-007--13182.35645.hdf5
# 4/4 [==============================] - 0s 20ms/step - loss: 13599.5127 - mean_absolute_error: 13599.5127 - val_loss: 13182.3564 - val_mean_absolute_error: 13182.3564
# Epoch 8/500
# 1/4 [======>.......................] - ETA: 0s - loss: 13953.2754 - mean_absolute_error: 13953.2754
# Epoch 8: val_loss improved from 13182.35645 to 13156.21680, saving model to Weights-008--13156.21680.hdf5
# 4/4 [==============================] - 0s 21ms/step - loss: 13572.6182 - mean_absolute_error: 13572.6182 - val_loss: 13156.2168 - val_mean_absolute_error: 13156.2168
# Epoch 9/500
# 1/4 [======>.......................] - ETA: 0s - loss: 12610.7910 - mean_absolute_error: 12610.7910
# Epoch 9: val_loss improved from 13156.21680 to 13117.02344, saving model to Weights-009--13117.02344.hdf5
# 4/4 [==============================] - 0s 20ms/step - loss: 13530.9521 - mean_absolute_error: 13530.9521 - val_loss: 13117.0234 - val_mean_absolute_error: 13117.0234
# Epoch 10/500
# 1/4 [======>.......................] - ETA: 0s - loss: 14548.8750 - mean_absolute_error: 14548.8750
# Epoch 10: val_loss improved from 13117.02344 to 13060.05859, saving model to Weights-010--13060.05859.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 13467.3359 - mean_absolute_error: 13467.3359 - val_loss: 13060.0586 - val_mean_absolute_error: 13060.0586
# Epoch 11/500
# 1/4 [======>.......................] - ETA: 0s - loss: 11422.3828 - mean_absolute_error: 11422.3828
# Epoch 11: val_loss improved from 13060.05859 to 12978.96875, saving model to Weights-011--12978.96875.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 13374.9014 - mean_absolute_error: 13374.9014 - val_loss: 12978.9688 - val_mean_absolute_error: 12978.9688
# Epoch 12/500
# 1/4 [======>.......................] - ETA: 0s - loss: 12984.9297 - mean_absolute_error: 12984.9297
# Epoch 12: val_loss improved from 12978.96875 to 12865.84668, saving model to Weights-012--12865.84668.hdf5
# 4/4 [==============================] - 0s 20ms/step - loss: 13240.1172 - mean_absolute_error: 13240.1172 - val_loss: 12865.8467 - val_mean_absolute_error: 12865.8467
# Epoch 13/500
# 1/4 [======>.......................] - ETA: 0s - loss: 13041.0820 - mean_absolute_error: 13041.0820
# Epoch 13: val_loss improved from 12865.84668 to 12712.75000, saving model to Weights-013--12712.75000.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 13060.8838 - mean_absolute_error: 13060.8838 - val_loss: 12712.7500 - val_mean_absolute_error: 12712.7500
# Epoch 14/500
# 1/4 [======>.......................] - ETA: 0s - loss: 13218.4795 - mean_absolute_error: 13218.4795
# Epoch 14: val_loss improved from 12712.75000 to 12506.33594, saving model to Weights-014--12506.33594.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 12809.2959 - mean_absolute_error: 12809.2959 - val_loss: 12506.3359 - val_mean_absolute_error: 12506.3359
# Epoch 15/500
# 1/4 [======>.......................] - ETA: 0s - loss: 11823.2109 - mean_absolute_error: 11823.2109
# Epoch 15: val_loss improved from 12506.33594 to 12231.41602, saving model to Weights-015--12231.41602.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 12465.1406 - mean_absolute_error: 12465.1406 - val_loss: 12231.4160 - val_mean_absolute_error: 12231.4160
# Epoch 16/500
# 1/4 [======>.......................] - ETA: 0s - loss: 11683.3945 - mean_absolute_error: 11683.3945
# Epoch 16: val_loss improved from 12231.41602 to 11868.86035, saving model to Weights-016--11868.86035.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 12001.7930 - mean_absolute_error: 12001.7930 - val_loss: 11868.8604 - val_mean_absolute_error: 11868.8604
# Epoch 17/500
# 1/4 [======>.......................] - ETA: 0s - loss: 11294.2686 - mean_absolute_error: 11294.2686
# Epoch 17: val_loss improved from 11868.86035 to 11399.12500, saving model to Weights-017--11399.12500.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 11408.6152 - mean_absolute_error: 11408.6152 - val_loss: 11399.1250 - val_mean_absolute_error: 11399.1250
# Epoch 18/500
# 1/4 [======>.......................] - ETA: 0s - loss: 10523.9189 - mean_absolute_error: 10523.9189
# Epoch 18: val_loss improved from 11399.12500 to 10798.40430, saving model to Weights-018--10798.40430.hdf5
# 4/4 [==============================] - 0s 20ms/step - loss: 10609.0742 - mean_absolute_error: 10609.0752 - val_loss: 10798.4043 - val_mean_absolute_error: 10798.4043
# Epoch 19/500
# 1/4 [======>.......................] - ETA: 0s - loss: 9088.9736 - mean_absolute_error: 9088.9736
# Epoch 19: val_loss improved from 10798.40430 to 10048.08203, saving model to Weights-019--10048.08203.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 9625.0605 - mean_absolute_error: 9625.0605 - val_loss: 10048.0820 - val_mean_absolute_error: 10048.0820
# Epoch 20/500
# 1/4 [======>.......................] - ETA: 0s - loss: 8539.5098 - mean_absolute_error: 8539.5098
# Epoch 20: val_loss improved from 10048.08203 to 9157.91797, saving model to Weights-020--9157.91797.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 8401.9961 - mean_absolute_error: 8401.9961 - val_loss: 9157.9180 - val_mean_absolute_error: 9157.9180
# Epoch 21/500
# 1/4 [======>.......................] - ETA: 0s - loss: 7115.8018 - mean_absolute_error: 7115.8018
# Epoch 21: val_loss improved from 9157.91797 to 8171.84033, saving model to Weights-021--8171.84033.hdf5
# 4/4 [==============================] - 0s 21ms/step - loss: 7061.1777 - mean_absolute_error: 7061.1777 - val_loss: 8171.8403 - val_mean_absolute_error: 8171.8403
# Epoch 22/500
# 1/4 [======>.......................] - ETA: 0s - loss: 5615.5684 - mean_absolute_error: 5615.5684
# Epoch 22: val_loss improved from 8171.84033 to 7280.05371, saving model to Weights-022--7280.05371.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 5767.2905 - mean_absolute_error: 5767.2905 - val_loss: 7280.0537 - val_mean_absolute_error: 7280.0537
# Epoch 23/500
# 1/4 [======>.......................] - ETA: 0s - loss: 3997.2593 - mean_absolute_error: 3997.2593
# Epoch 23: val_loss improved from 7280.05371 to 6792.67578, saving model to Weights-023--6792.67578.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 4718.6279 - mean_absolute_error: 4718.6279 - val_loss: 6792.6758 - val_mean_absolute_error: 6792.6758
# Epoch 24/500
# 1/4 [======>.......................] - ETA: 0s - loss: 3598.9304 - mean_absolute_error: 3598.9304
# Epoch 24: val_loss improved from 6792.67578 to 6548.19922, saving model to Weights-024--6548.19922.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 4107.5449 - mean_absolute_error: 4107.5449 - val_loss: 6548.1992 - val_mean_absolute_error: 6548.1992
# Epoch 25/500
# 1/4 [======>.......................] - ETA: 0s - loss: 4934.3208 - mean_absolute_error: 4934.3208
# Epoch 25: val_loss improved from 6548.19922 to 6277.80273, saving model to Weights-025--6277.80273.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 3884.7307 - mean_absolute_error: 3884.7307 - val_loss: 6277.8027 - val_mean_absolute_error: 6277.8027
# Epoch 26/500
# 1/4 [======>.......................] - ETA: 0s - loss: 3737.2014 - mean_absolute_error: 3737.2014
# Epoch 26: val_loss improved from 6277.80273 to 5952.63477, saving model to Weights-026--5952.63477.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 3621.8689 - mean_absolute_error: 3621.8689 - val_loss: 5952.6348 - val_mean_absolute_error: 5952.6348
# Epoch 27/500
# 1/4 [======>.......................] - ETA: 0s - loss: 4537.9258 - mean_absolute_error: 4537.9258
# Epoch 27: val_loss improved from 5952.63477 to 5670.61328, saving model to Weights-027--5670.61328.hdf5
# 4/4 [==============================] - 0s 28ms/step - loss: 3210.8772 - mean_absolute_error: 3210.8772 - val_loss: 5670.6133 - val_mean_absolute_error: 5670.6133
# Epoch 28/500
# 1/4 [======>.......................] - ETA: 0s - loss: 3042.3740 - mean_absolute_error: 3042.3740
# Epoch 28: val_loss improved from 5670.61328 to 5631.18848, saving model to Weights-028--5631.18848.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 2795.3157 - mean_absolute_error: 2795.3157 - val_loss: 5631.1885 - val_mean_absolute_error: 5631.1885
# Epoch 29/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2678.7803 - mean_absolute_error: 2678.7803
# Epoch 29: val_loss did not improve from 5631.18848
# 4/4 [==============================] - 0s 11ms/step - loss: 2518.9199 - mean_absolute_error: 2518.9199 - val_loss: 5637.2744 - val_mean_absolute_error: 5637.2744
# Epoch 30/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2752.5066 - mean_absolute_error: 2752.5066
# Epoch 30: val_loss improved from 5631.18848 to 5497.30957, saving model to Weights-030--5497.30957.hdf5
# 4/4 [==============================] - 0s 17ms/step - loss: 2399.5693 - mean_absolute_error: 2399.5693 - val_loss: 5497.3096 - val_mean_absolute_error: 5497.3096
# Epoch 31/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2354.5627 - mean_absolute_error: 2354.5627
# Epoch 31: val_loss improved from 5497.30957 to 5267.29541, saving model to Weights-031--5267.29541.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 2215.2126 - mean_absolute_error: 2215.2126 - val_loss: 5267.2954 - val_mean_absolute_error: 5267.2954
# Epoch 32/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1958.1935 - mean_absolute_error: 1958.1935
# Epoch 32: val_loss improved from 5267.29541 to 5030.54541, saving model to Weights-032--5030.54541.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 2126.3242 - mean_absolute_error: 2126.3242 - val_loss: 5030.5454 - val_mean_absolute_error: 5030.5454
# Epoch 33/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2236.5869 - mean_absolute_error: 2236.5869
# Epoch 33: val_loss improved from 5030.54541 to 4996.85498, saving model to Weights-033--4996.85498.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 2095.0867 - mean_absolute_error: 2095.0867 - val_loss: 4996.8550 - val_mean_absolute_error: 4996.8550
# Epoch 34/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2362.6265 - mean_absolute_error: 2362.6265
# Epoch 34: val_loss did not improve from 4996.85498
# 4/4 [==============================] - 0s 12ms/step - loss: 1942.9298 - mean_absolute_error: 1942.9298 - val_loss: 5050.6562 - val_mean_absolute_error: 5050.6562
# Epoch 35/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1531.7803 - mean_absolute_error: 1531.7803
# Epoch 35: val_loss improved from 4996.85498 to 4985.42139, saving model to Weights-035--4985.42139.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 1870.2186 - mean_absolute_error: 1870.2186 - val_loss: 4985.4214 - val_mean_absolute_error: 4985.4214
# Epoch 36/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1653.6951 - mean_absolute_error: 1653.6951
# Epoch 36: val_loss improved from 4985.42139 to 4882.05811, saving model to Weights-036--4882.05811.hdf5
# 4/4 [==============================] - 0s 21ms/step - loss: 1788.9774 - mean_absolute_error: 1788.9774 - val_loss: 4882.0581 - val_mean_absolute_error: 4882.0581
# Epoch 37/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1380.0387 - mean_absolute_error: 1380.0387
# Epoch 37: val_loss improved from 4882.05811 to 4787.51709, saving model to Weights-037--4787.51709.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 1696.8857 - mean_absolute_error: 1696.8857 - val_loss: 4787.5171 - val_mean_absolute_error: 4787.5171
# Epoch 38/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1696.6396 - mean_absolute_error: 1696.6396
# Epoch 38: val_loss improved from 4787.51709 to 4682.87402, saving model to Weights-038--4682.87402.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 1639.8311 - mean_absolute_error: 1639.8311 - val_loss: 4682.8740 - val_mean_absolute_error: 4682.8740
# Epoch 39/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2048.5977 - mean_absolute_error: 2048.5977
# Epoch 39: val_loss improved from 4682.87402 to 4620.95459, saving model to Weights-039--4620.95459.hdf5
# 4/4 [==============================] - 0s 25ms/step - loss: 1581.7534 - mean_absolute_error: 1581.7534 - val_loss: 4620.9546 - val_mean_absolute_error: 4620.9546
# Epoch 40/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1911.0105 - mean_absolute_error: 1911.0105
# Epoch 40: val_loss improved from 4620.95459 to 4529.45898, saving model to Weights-040--4529.45898.hdf5
# 4/4 [==============================] - 0s 29ms/step - loss: 1499.6240 - mean_absolute_error: 1499.6240 - val_loss: 4529.4590 - val_mean_absolute_error: 4529.4590
# Epoch 41/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1784.3589 - mean_absolute_error: 1784.3589
# Epoch 41: val_loss improved from 4529.45898 to 4502.46045, saving model to Weights-041--4502.46045.hdf5
# 4/4 [==============================] - 0s 20ms/step - loss: 1447.6475 - mean_absolute_error: 1447.6475 - val_loss: 4502.4604 - val_mean_absolute_error: 4502.4604
# Epoch 42/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1363.6188 - mean_absolute_error: 1363.6188
# Epoch 42: val_loss improved from 4502.46045 to 4417.38477, saving model to Weights-042--4417.38477.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 1402.4568 - mean_absolute_error: 1402.4568 - val_loss: 4417.3848 - val_mean_absolute_error: 4417.3848
# Epoch 43/500
# 1/4 [======>.......................] - ETA: 0s - loss: 859.0192 - mean_absolute_error: 859.0192
# Epoch 43: val_loss improved from 4417.38477 to 4332.20605, saving model to Weights-043--4332.20605.hdf5
# 4/4 [==============================] - 0s 20ms/step - loss: 1349.3657 - mean_absolute_error: 1349.3657 - val_loss: 4332.2061 - val_mean_absolute_error: 4332.2061
# Epoch 44/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1224.8075 - mean_absolute_error: 1224.8075
# Epoch 44: val_loss improved from 4332.20605 to 4324.21436, saving model to Weights-044--4324.21436.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 1301.1724 - mean_absolute_error: 1301.1724 - val_loss: 4324.2144 - val_mean_absolute_error: 4324.2144
# Epoch 45/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1361.5806 - mean_absolute_error: 1361.5806
# Epoch 45: val_loss improved from 4324.21436 to 4251.70264, saving model to Weights-045--4251.70264.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 1279.4764 - mean_absolute_error: 1279.4764 - val_loss: 4251.7026 - val_mean_absolute_error: 4251.7026
# Epoch 46/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1545.6572 - mean_absolute_error: 1545.6572
# Epoch 46: val_loss improved from 4251.70264 to 4101.64990, saving model to Weights-046--4101.64990.hdf5
# 4/4 [==============================] - 0s 21ms/step - loss: 1218.9106 - mean_absolute_error: 1218.9106 - val_loss: 4101.6499 - val_mean_absolute_error: 4101.6499
# Epoch 47/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1548.1663 - mean_absolute_error: 1548.1663
# Epoch 47: val_loss did not improve from 4101.64990
# 4/4 [==============================] - 0s 10ms/step - loss: 1194.9529 - mean_absolute_error: 1194.9529 - val_loss: 4101.7573 - val_mean_absolute_error: 4101.7573
# Epoch 48/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1184.3994 - mean_absolute_error: 1184.3994
# Epoch 48: val_loss improved from 4101.64990 to 4035.54443, saving model to Weights-048--4035.54443.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 1155.7771 - mean_absolute_error: 1155.7771 - val_loss: 4035.5444 - val_mean_absolute_error: 4035.5444
# Epoch 49/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1157.6967 - mean_absolute_error: 1157.6967
# Epoch 49: val_loss improved from 4035.54443 to 3969.35352, saving model to Weights-049--3969.35352.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 1123.3894 - mean_absolute_error: 1123.3894 - val_loss: 3969.3535 - val_mean_absolute_error: 3969.3535
# Epoch 50/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1400.6045 - mean_absolute_error: 1400.6045
# Epoch 50: val_loss improved from 3969.35352 to 3944.00586, saving model to Weights-050--3944.00586.hdf5
# 4/4 [==============================] - 0s 31ms/step - loss: 1085.1245 - mean_absolute_error: 1085.1244 - val_loss: 3944.0059 - val_mean_absolute_error: 3944.0059
# Epoch 51/500
# 1/4 [======>.......................] - ETA: 0s - loss: 808.9045 - mean_absolute_error: 808.9045
# Epoch 51: val_loss improved from 3944.00586 to 3866.58569, saving model to Weights-051--3866.58569.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 1069.7963 - mean_absolute_error: 1069.7963 - val_loss: 3866.5857 - val_mean_absolute_error: 3866.5857
# Epoch 52/500
# 1/4 [======>.......................] - ETA: 0s - loss: 976.1495 - mean_absolute_error: 976.1495
# Epoch 52: val_loss improved from 3866.58569 to 3809.50537, saving model to Weights-052--3809.50537.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 1039.2273 - mean_absolute_error: 1039.2273 - val_loss: 3809.5054 - val_mean_absolute_error: 3809.5054
# Epoch 53/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1248.1699 - mean_absolute_error: 1248.1699
# Epoch 53: val_loss improved from 3809.50537 to 3705.93115, saving model to Weights-053--3705.93115.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 1013.9017 - mean_absolute_error: 1013.9017 - val_loss: 3705.9312 - val_mean_absolute_error: 3705.9312
# Epoch 54/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1201.3285 - mean_absolute_error: 1201.3285
# Epoch 54: val_loss improved from 3705.93115 to 3569.10229, saving model to Weights-054--3569.10229.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 1000.2521 - mean_absolute_error: 1000.2521 - val_loss: 3569.1023 - val_mean_absolute_error: 3569.1023
# Epoch 55/500
# 1/4 [======>.......................] - ETA: 0s - loss: 738.8947 - mean_absolute_error: 738.8947
# Epoch 55: val_loss did not improve from 3569.10229
# 4/4 [==============================] - 0s 18ms/step - loss: 1003.4684 - mean_absolute_error: 1003.4684 - val_loss: 3578.3391 - val_mean_absolute_error: 3578.3391
# Epoch 56/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1046.0044 - mean_absolute_error: 1046.0044
# Epoch 56: val_loss improved from 3569.10229 to 3556.02417, saving model to Weights-056--3556.02417.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 1005.7916 - mean_absolute_error: 1005.7916 - val_loss: 3556.0242 - val_mean_absolute_error: 3556.0242
# Epoch 57/500
# 1/4 [======>.......................] - ETA: 0s - loss: 962.9840 - mean_absolute_error: 962.9840
# Epoch 57: val_loss improved from 3556.02417 to 3413.60742, saving model to Weights-057--3413.60742.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 927.2521 - mean_absolute_error: 927.2521 - val_loss: 3413.6074 - val_mean_absolute_error: 3413.6074
# Epoch 58/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1181.1882 - mean_absolute_error: 1181.1882
# Epoch 58: val_loss did not improve from 3413.60742
# 4/4 [==============================] - 0s 18ms/step - loss: 917.6854 - mean_absolute_error: 917.6854 - val_loss: 3428.9292 - val_mean_absolute_error: 3428.9292
# Epoch 59/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1058.6277 - mean_absolute_error: 1058.6277
# Epoch 59: val_loss improved from 3413.60742 to 3327.95361, saving model to Weights-059--3327.95361.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 902.7612 - mean_absolute_error: 902.7612 - val_loss: 3327.9536 - val_mean_absolute_error: 3327.9536
# Epoch 60/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1062.6643 - mean_absolute_error: 1062.6643
# Epoch 60: val_loss improved from 3327.95361 to 3294.09204, saving model to Weights-060--3294.09204.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 872.8193 - mean_absolute_error: 872.8193 - val_loss: 3294.0920 - val_mean_absolute_error: 3294.0920
# Epoch 61/500
# 1/4 [======>.......................] - ETA: 0s - loss: 836.1882 - mean_absolute_error: 836.1882
# Epoch 61: val_loss improved from 3294.09204 to 3291.85596, saving model to Weights-061--3291.85596.hdf5
# 4/4 [==============================] - 0s 20ms/step - loss: 846.5565 - mean_absolute_error: 846.5565 - val_loss: 3291.8560 - val_mean_absolute_error: 3291.8560
# Epoch 62/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1008.9854 - mean_absolute_error: 1008.9854
# Epoch 62: val_loss improved from 3291.85596 to 3183.03198, saving model to Weights-062--3183.03198.hdf5
# 4/4 [==============================] - 0s 22ms/step - loss: 837.2577 - mean_absolute_error: 837.2577 - val_loss: 3183.0320 - val_mean_absolute_error: 3183.0320
# Epoch 63/500
# 1/4 [======>.......................] - ETA: 0s - loss: 998.2327 - mean_absolute_error: 998.2327
# Epoch 63: val_loss improved from 3183.03198 to 3178.74316, saving model to Weights-063--3178.74316.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 821.4877 - mean_absolute_error: 821.4877 - val_loss: 3178.7432 - val_mean_absolute_error: 3178.7432
# Epoch 64/500
# 1/4 [======>.......................] - ETA: 0s - loss: 839.4427 - mean_absolute_error: 839.4427
# Epoch 64: val_loss improved from 3178.74316 to 3109.56738, saving model to Weights-064--3109.56738.hdf5
# 4/4 [==============================] - 0s 20ms/step - loss: 818.4456 - mean_absolute_error: 818.4456 - val_loss: 3109.5674 - val_mean_absolute_error: 3109.5674
# Epoch 65/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1072.9028 - mean_absolute_error: 1072.9028
# Epoch 65: val_loss improved from 3109.56738 to 3064.81934, saving model to Weights-065--3064.81934.hdf5
# 4/4 [==============================] - 0s 20ms/step - loss: 812.9689 - mean_absolute_error: 812.9689 - val_loss: 3064.8193 - val_mean_absolute_error: 3064.8193
# Epoch 66/500
# 1/4 [======>.......................] - ETA: 0s - loss: 580.5157 - mean_absolute_error: 580.5157
# Epoch 66: val_loss did not improve from 3064.81934
# 4/4 [==============================] - 0s 13ms/step - loss: 790.5056 - mean_absolute_error: 790.5056 - val_loss: 3065.4216 - val_mean_absolute_error: 3065.4216
# Epoch 67/500
# 1/4 [======>.......................] - ETA: 0s - loss: 697.3367 - mean_absolute_error: 697.3367
# Epoch 67: val_loss improved from 3064.81934 to 2975.05396, saving model to Weights-067--2975.05396.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 768.9655 - mean_absolute_error: 768.9655 - val_loss: 2975.0540 - val_mean_absolute_error: 2975.0540
# Epoch 68/500
# 1/4 [======>.......................] - ETA: 0s - loss: 840.8774 - mean_absolute_error: 840.8774
# Epoch 68: val_loss improved from 2975.05396 to 2948.33228, saving model to Weights-068--2948.33228.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 753.6585 - mean_absolute_error: 753.6585 - val_loss: 2948.3323 - val_mean_absolute_error: 2948.3323
# Epoch 69/500
# 1/4 [======>.......................] - ETA: 0s - loss: 764.9897 - mean_absolute_error: 764.9897
# Epoch 69: val_loss improved from 2948.33228 to 2905.91113, saving model to Weights-069--2905.91113.hdf5
# 4/4 [==============================] - 0s 22ms/step - loss: 725.8740 - mean_absolute_error: 725.8740 - val_loss: 2905.9111 - val_mean_absolute_error: 2905.9111
# Epoch 70/500
# 1/4 [======>.......................] - ETA: 0s - loss: 391.0864 - mean_absolute_error: 391.0864
# Epoch 70: val_loss improved from 2905.91113 to 2903.17993, saving model to Weights-070--2903.17993.hdf5
# 4/4 [==============================] - 0s 20ms/step - loss: 732.5184 - mean_absolute_error: 732.5184 - val_loss: 2903.1799 - val_mean_absolute_error: 2903.1799
# Epoch 71/500
# 1/4 [======>.......................] - ETA: 0s - loss: 818.4215 - mean_absolute_error: 818.4215
# Epoch 71: val_loss improved from 2903.17993 to 2841.93164, saving model to Weights-071--2841.93164.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 740.8708 - mean_absolute_error: 740.8708 - val_loss: 2841.9316 - val_mean_absolute_error: 2841.9316
# Epoch 72/500
# 1/4 [======>.......................] - ETA: 0s - loss: 490.4540 - mean_absolute_error: 490.4540
# Epoch 72: val_loss improved from 2841.93164 to 2759.15771, saving model to Weights-072--2759.15771.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 715.0043 - mean_absolute_error: 715.0043 - val_loss: 2759.1577 - val_mean_absolute_error: 2759.1577
# Epoch 73/500
# 1/4 [======>.......................] - ETA: 0s - loss: 689.1795 - mean_absolute_error: 689.1795
# Epoch 73: val_loss did not improve from 2759.15771
# 4/4 [==============================] - 0s 11ms/step - loss: 684.5149 - mean_absolute_error: 684.5149 - val_loss: 2792.5132 - val_mean_absolute_error: 2792.5132
# Epoch 74/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1141.4833 - mean_absolute_error: 1141.4833
# Epoch 74: val_loss improved from 2759.15771 to 2708.98706, saving model to Weights-074--2708.98706.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 710.9940 - mean_absolute_error: 710.9940 - val_loss: 2708.9871 - val_mean_absolute_error: 2708.9871
# Epoch 75/500
# 1/4 [======>.......................] - ETA: 0s - loss: 916.5802 - mean_absolute_error: 916.5802
# Epoch 75: val_loss did not improve from 2708.98706
# 4/4 [==============================] - 0s 11ms/step - loss: 719.9548 - mean_absolute_error: 719.9548 - val_loss: 2714.9739 - val_mean_absolute_error: 2714.9739
# Epoch 76/500
# 1/4 [======>.......................] - ETA: 0s - loss: 382.0315 - mean_absolute_error: 382.0315
# Epoch 76: val_loss did not improve from 2708.98706
# 4/4 [==============================] - 0s 18ms/step - loss: 668.2081 - mean_absolute_error: 668.2081 - val_loss: 2720.8643 - val_mean_absolute_error: 2720.8643
# Epoch 77/500
# 1/4 [======>.......................] - ETA: 0s - loss: 654.7155 - mean_absolute_error: 654.7155
# Epoch 77: val_loss improved from 2708.98706 to 2667.77417, saving model to Weights-077--2667.77417.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 641.7070 - mean_absolute_error: 641.7070 - val_loss: 2667.7742 - val_mean_absolute_error: 2667.7742
# Epoch 78/500
# 1/4 [======>.......................] - ETA: 0s - loss: 555.3774 - mean_absolute_error: 555.3774
# Epoch 78: val_loss did not improve from 2667.77417
# 4/4 [==============================] - 0s 17ms/step - loss: 631.1743 - mean_absolute_error: 631.1743 - val_loss: 2693.5220 - val_mean_absolute_error: 2693.5220
# Epoch 79/500
# 1/4 [======>.......................] - ETA: 0s - loss: 544.8275 - mean_absolute_error: 544.8275
# Epoch 79: val_loss did not improve from 2667.77417
# 4/4 [==============================] - 0s 10ms/step - loss: 650.8002 - mean_absolute_error: 650.8002 - val_loss: 2684.1743 - val_mean_absolute_error: 2684.1743
# Epoch 80/500
# 1/4 [======>.......................] - ETA: 0s - loss: 977.1431 - mean_absolute_error: 977.1431
# Epoch 80: val_loss did not improve from 2667.77417
# 4/4 [==============================] - 0s 13ms/step - loss: 638.9020 - mean_absolute_error: 638.9020 - val_loss: 2695.1768 - val_mean_absolute_error: 2695.1768
# Epoch 81/500
# 1/4 [======>.......................] - ETA: 0s - loss: 384.2526 - mean_absolute_error: 384.2526
# Epoch 81: val_loss did not improve from 2667.77417
# 4/4 [==============================] - 0s 12ms/step - loss: 624.6643 - mean_absolute_error: 624.6643 - val_loss: 2673.0022 - val_mean_absolute_error: 2673.0022
# Epoch 82/500
# 1/4 [======>.......................] - ETA: 0s - loss: 440.2798 - mean_absolute_error: 440.2798
# Epoch 82: val_loss did not improve from 2667.77417
# 4/4 [==============================] - 0s 13ms/step - loss: 630.6951 - mean_absolute_error: 630.6951 - val_loss: 2678.9568 - val_mean_absolute_error: 2678.9568
# Epoch 83/500
# 1/4 [======>.......................] - ETA: 0s - loss: 637.9126 - mean_absolute_error: 637.9126
# Epoch 83: val_loss did not improve from 2667.77417
# 4/4 [==============================] - 0s 18ms/step - loss: 614.3071 - mean_absolute_error: 614.3071 - val_loss: 2704.9255 - val_mean_absolute_error: 2704.9255
# Epoch 84/500
# 1/4 [======>.......................] - ETA: 0s - loss: 488.6487 - mean_absolute_error: 488.6487
# Epoch 84: val_loss did not improve from 2667.77417
# 4/4 [==============================] - 0s 12ms/step - loss: 615.0743 - mean_absolute_error: 615.0743 - val_loss: 2681.1260 - val_mean_absolute_error: 2681.1260
# Epoch 85/500
# 1/4 [======>.......................] - ETA: 0s - loss: 412.3900 - mean_absolute_error: 412.3900
# Epoch 85: val_loss did not improve from 2667.77417
# 4/4 [==============================] - 0s 11ms/step - loss: 588.4868 - mean_absolute_error: 588.4868 - val_loss: 2683.7412 - val_mean_absolute_error: 2683.7412
# Epoch 86/500
# 1/4 [======>.......................] - ETA: 0s - loss: 548.5219 - mean_absolute_error: 548.5219
# Epoch 86: val_loss improved from 2667.77417 to 2649.44312, saving model to Weights-086--2649.44312.hdf5
# 4/4 [==============================] - 0s 19ms/step - loss: 597.5630 - mean_absolute_error: 597.5630 - val_loss: 2649.4431 - val_mean_absolute_error: 2649.4431
# Epoch 87/500
# 1/4 [======>.......................] - ETA: 0s - loss: 508.9291 - mean_absolute_error: 508.9291
# Epoch 87: val_loss did not improve from 2649.44312
# 4/4 [==============================] - 0s 13ms/step - loss: 592.9466 - mean_absolute_error: 592.9466 - val_loss: 2671.9219 - val_mean_absolute_error: 2671.9219
# Epoch 88/500
# 1/4 [======>.......................] - ETA: 0s - loss: 881.5221 - mean_absolute_error: 881.5221
# Epoch 88: val_loss did not improve from 2649.44312
# 4/4 [==============================] - 0s 12ms/step - loss: 577.6055 - mean_absolute_error: 577.6055 - val_loss: 2655.7764 - val_mean_absolute_error: 2655.7764
# Epoch 89/500
# 1/4 [======>.......................] - ETA: 0s - loss: 481.8410 - mean_absolute_error: 481.8410
# Epoch 89: val_loss improved from 2649.44312 to 2633.27368, saving model to Weights-089--2633.27368.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 568.1198 - mean_absolute_error: 568.1198 - val_loss: 2633.2737 - val_mean_absolute_error: 2633.2737
# Epoch 90/500
# 1/4 [======>.......................] - ETA: 0s - loss: 496.3767 - mean_absolute_error: 496.3767
# Epoch 90: val_loss did not improve from 2633.27368
# 4/4 [==============================] - 0s 11ms/step - loss: 557.1473 - mean_absolute_error: 557.1473 - val_loss: 2651.2239 - val_mean_absolute_error: 2651.2239
# Epoch 91/500
# 1/4 [======>.......................] - ETA: 0s - loss: 434.6145 - mean_absolute_error: 434.6145
# Epoch 91: val_loss improved from 2633.27368 to 2625.50806, saving model to Weights-091--2625.50806.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 550.3412 - mean_absolute_error: 550.3412 - val_loss: 2625.5081 - val_mean_absolute_error: 2625.5081
# Epoch 92/500
# 1/4 [======>.......................] - ETA: 0s - loss: 554.8026 - mean_absolute_error: 554.8026
# Epoch 92: val_loss did not improve from 2625.50806
# 4/4 [==============================] - 0s 18ms/step - loss: 573.5747 - mean_absolute_error: 573.5747 - val_loss: 2650.8337 - val_mean_absolute_error: 2650.8337
# Epoch 93/500
# 1/4 [======>.......................] - ETA: 0s - loss: 652.4126 - mean_absolute_error: 652.4126
# Epoch 93: val_loss did not improve from 2625.50806
# 4/4 [==============================] - 0s 12ms/step - loss: 545.4465 - mean_absolute_error: 545.4465 - val_loss: 2654.6843 - val_mean_absolute_error: 2654.6843
# Epoch 94/500
# 1/4 [======>.......................] - ETA: 0s - loss: 482.6808 - mean_absolute_error: 482.6808
# Epoch 94: val_loss did not improve from 2625.50806
# 4/4 [==============================] - 0s 11ms/step - loss: 545.5799 - mean_absolute_error: 545.5799 - val_loss: 2644.4375 - val_mean_absolute_error: 2644.4375
# Epoch 95/500
# 1/4 [======>.......................] - ETA: 0s - loss: 194.5242 - mean_absolute_error: 194.5242
# Epoch 95: val_loss did not improve from 2625.50806
# 4/4 [==============================] - 0s 10ms/step - loss: 552.6363 - mean_absolute_error: 552.6363 - val_loss: 2627.4016 - val_mean_absolute_error: 2627.4016
# Epoch 96/500
# 1/4 [======>.......................] - ETA: 0s - loss: 433.5919 - mean_absolute_error: 433.5919
# Epoch 96: val_loss did not improve from 2625.50806
# 4/4 [==============================] - 0s 11ms/step - loss: 547.6033 - mean_absolute_error: 547.6033 - val_loss: 2651.0625 - val_mean_absolute_error: 2651.0625
# Epoch 97/500
# 1/4 [======>.......................] - ETA: 0s - loss: 450.8587 - mean_absolute_error: 450.8587
# Epoch 97: val_loss improved from 2625.50806 to 2618.19214, saving model to Weights-097--2618.19214.hdf5
# 4/4 [==============================] - 0s 18ms/step - loss: 538.0557 - mean_absolute_error: 538.0557 - val_loss: 2618.1921 - val_mean_absolute_error: 2618.1921
# Epoch 98/500
# 1/4 [======>.......................] - ETA: 0s - loss: 640.8976 - mean_absolute_error: 640.8976
# Epoch 98: val_loss did not improve from 2618.19214
# 4/4 [==============================] - 0s 11ms/step - loss: 554.7521 - mean_absolute_error: 554.7521 - val_loss: 2654.1311 - val_mean_absolute_error: 2654.1311
# Epoch 99/500
# 1/4 [======>.......................] - ETA: 0s - loss: 870.8242 - mean_absolute_error: 870.8242
# Epoch 99: val_loss did not improve from 2618.19214
# 4/4 [==============================] - 0s 13ms/step - loss: 606.9532 - mean_absolute_error: 606.9532 - val_loss: 2635.0884 - val_mean_absolute_error: 2635.0884
# Epoch 100/500
# 1/4 [======>.......................] - ETA: 0s - loss: 661.7299 - mean_absolute_error: 661.7299
# Epoch 100: val_loss improved from 2618.19214 to 2605.37598, saving model to Weights-100--2605.37598.hdf5
# 4/4 [==============================] - 0s 20ms/step - loss: 539.1459 - mean_absolute_error: 539.1459 - val_loss: 2605.3760 - val_mean_absolute_error: 2605.3760
# Epoch 101/500
# 1/4 [======>.......................] - ETA: 0s - loss: 343.2461 - mean_absolute_error: 343.2461
# Epoch 101: val_loss did not improve from 2605.37598
# 4/4 [==============================] - 0s 11ms/step - loss: 535.9385 - mean_absolute_error: 535.9385 - val_loss: 2621.1123 - val_mean_absolute_error: 2621.1123
# Epoch 102/500
# 1/4 [======>.......................] - ETA: 0s - loss: 394.0131 - mean_absolute_error: 394.0131
# Epoch 102: val_loss improved from 2605.37598 to 2583.80640, saving model to Weights-102--2583.80640.hdf5
# 4/4 [==============================] - 0s 20ms/step - loss: 517.6608 - mean_absolute_error: 517.6608 - val_loss: 2583.8064 - val_mean_absolute_error: 2583.8064
# Epoch 103/500
# 1/4 [======>.......................] - ETA: 0s - loss: 559.6196 - mean_absolute_error: 559.6196
# Epoch 103: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 11ms/step - loss: 552.4703 - mean_absolute_error: 552.4703 - val_loss: 2635.8896 - val_mean_absolute_error: 2635.8896
# Epoch 104/500
# 1/4 [======>.......................] - ETA: 0s - loss: 352.3642 - mean_absolute_error: 352.3642
# Epoch 104: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 11ms/step - loss: 564.0125 - mean_absolute_error: 564.0125 - val_loss: 2646.5049 - val_mean_absolute_error: 2646.5049
# Epoch 105/500
# 1/4 [======>.......................] - ETA: 0s - loss: 702.0382 - mean_absolute_error: 702.0382
# Epoch 105: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 13ms/step - loss: 528.5167 - mean_absolute_error: 528.5167 - val_loss: 2652.3643 - val_mean_absolute_error: 2652.3643
# Epoch 106/500
# 1/4 [======>.......................] - ETA: 0s - loss: 795.2484 - mean_absolute_error: 795.2484
# Epoch 106: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 12ms/step - loss: 514.7924 - mean_absolute_error: 514.7924 - val_loss: 2633.4209 - val_mean_absolute_error: 2633.4209
# Epoch 107/500
# 1/4 [======>.......................] - ETA: 0s - loss: 632.5552 - mean_absolute_error: 632.5552
# Epoch 107: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 11ms/step - loss: 496.6212 - mean_absolute_error: 496.6212 - val_loss: 2611.7161 - val_mean_absolute_error: 2611.7161
# Epoch 108/500
# 1/4 [======>.......................] - ETA: 0s - loss: 685.6695 - mean_absolute_error: 685.6695
# Epoch 108: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 12ms/step - loss: 492.0028 - mean_absolute_error: 492.0028 - val_loss: 2595.9053 - val_mean_absolute_error: 2595.9053
# Epoch 109/500
# 1/4 [======>.......................] - ETA: 0s - loss: 213.9158 - mean_absolute_error: 213.9158
# Epoch 109: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 12ms/step - loss: 489.5636 - mean_absolute_error: 489.5636 - val_loss: 2615.0789 - val_mean_absolute_error: 2615.0789
# Epoch 110/500
# 1/4 [======>.......................] - ETA: 0s - loss: 331.9009 - mean_absolute_error: 331.9009
# Epoch 110: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 12ms/step - loss: 497.7400 - mean_absolute_error: 497.7400 - val_loss: 2597.2720 - val_mean_absolute_error: 2597.2720
# Epoch 111/500
# 1/4 [======>.......................] - ETA: 0s - loss: 405.7723 - mean_absolute_error: 405.7723
# Epoch 111: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 12ms/step - loss: 522.7129 - mean_absolute_error: 522.7129 - val_loss: 2611.1321 - val_mean_absolute_error: 2611.1321
# Epoch 112/500
# 1/4 [======>.......................] - ETA: 0s - loss: 319.1547 - mean_absolute_error: 319.1547
# Epoch 112: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 13ms/step - loss: 513.7939 - mean_absolute_error: 513.7939 - val_loss: 2604.3369 - val_mean_absolute_error: 2604.3369
# Epoch 113/500
# 1/4 [======>.......................] - ETA: 0s - loss: 482.7079 - mean_absolute_error: 482.7079
# Epoch 113: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 12ms/step - loss: 484.8445 - mean_absolute_error: 484.8445 - val_loss: 2601.7991 - val_mean_absolute_error: 2601.7991
# Epoch 114/500
# 1/4 [======>.......................] - ETA: 0s - loss: 299.7989 - mean_absolute_error: 299.7989
# Epoch 114: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 12ms/step - loss: 482.3298 - mean_absolute_error: 482.3298 - val_loss: 2614.7214 - val_mean_absolute_error: 2614.7214
# Epoch 115/500
# 1/4 [======>.......................] - ETA: 0s - loss: 456.5885 - mean_absolute_error: 456.5885
# Epoch 115: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 13ms/step - loss: 481.3091 - mean_absolute_error: 481.3091 - val_loss: 2617.7966 - val_mean_absolute_error: 2617.7966
# Epoch 116/500
# 1/4 [======>.......................] - ETA: 0s - loss: 176.6730 - mean_absolute_error: 176.6730
# Epoch 116: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 12ms/step - loss: 461.7888 - mean_absolute_error: 461.7888 - val_loss: 2628.6370 - val_mean_absolute_error: 2628.6370
# Epoch 117/500
# 1/4 [======>.......................] - ETA: 0s - loss: 396.7918 - mean_absolute_error: 396.7918
# Epoch 117: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 18ms/step - loss: 468.0797 - mean_absolute_error: 468.0797 - val_loss: 2609.1904 - val_mean_absolute_error: 2609.1904
# Epoch 118/500
# 1/4 [======>.......................] - ETA: 0s - loss: 380.0704 - mean_absolute_error: 380.0704
# Epoch 118: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 15ms/step - loss: 468.5010 - mean_absolute_error: 468.5010 - val_loss: 2610.0701 - val_mean_absolute_error: 2610.0701
# Epoch 119/500
# 1/4 [======>.......................] - ETA: 0s - loss: 348.4919 - mean_absolute_error: 348.4919
# Epoch 119: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 12ms/step - loss: 462.5765 - mean_absolute_error: 462.5765 - val_loss: 2595.1746 - val_mean_absolute_error: 2595.1746
# Epoch 120/500
# 1/4 [======>.......................] - ETA: 0s - loss: 321.3800 - mean_absolute_error: 321.3800
# Epoch 120: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 12ms/step - loss: 458.9656 - mean_absolute_error: 458.9656 - val_loss: 2609.4719 - val_mean_absolute_error: 2609.4719
# Epoch 121/500
# 1/4 [======>.......................] - ETA: 0s - loss: 464.2268 - mean_absolute_error: 464.2268
# Epoch 121: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 13ms/step - loss: 460.2711 - mean_absolute_error: 460.2711 - val_loss: 2598.2549 - val_mean_absolute_error: 2598.2549
# Epoch 122/500
# 1/4 [======>.......................] - ETA: 0s - loss: 367.5223 - mean_absolute_error: 367.5223
# Epoch 122: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 12ms/step - loss: 465.4295 - mean_absolute_error: 465.4295 - val_loss: 2618.4651 - val_mean_absolute_error: 2618.4651
# Epoch 123/500
# 1/4 [======>.......................] - ETA: 0s - loss: 803.4521 - mean_absolute_error: 803.4521
# Epoch 123: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 13ms/step - loss: 474.6127 - mean_absolute_error: 474.6127 - val_loss: 2610.8218 - val_mean_absolute_error: 2610.8218
# Epoch 124/500
# 1/4 [======>.......................] - ETA: 0s - loss: 612.1121 - mean_absolute_error: 612.1121
# Epoch 124: val_loss did not improve from 2583.80640
# 4/4 [==============================] - 0s 12ms/step - loss: 457.0355 - mean_absolute_error: 457.0355 - val_loss: 2597.8123 - val_mean_absolute_error: 2597.8123
# Epoch 125/500
# 1/4 [======>.......................] - ETA: 0s - loss: 294.0507 - mean_absolute_error: 294.0507
# Epoch 125: val_loss improved from 2583.80640 to 2572.08325, saving model to Weights-125--2572.08325.hdf5
# 4/4 [==============================] - 0s 21ms/step - loss: 462.8439 - mean_absolute_error: 462.8439 - val_loss: 2572.0833 - val_mean_absolute_error: 2572.0833
# Epoch 126/500
# 1/4 [======>.......................] - ETA: 0s - loss: 282.1463 - mean_absolute_error: 282.1463
# Epoch 126: val_loss did not improve from 2572.08325
# 4/4 [==============================] - 0s 13ms/step - loss: 465.3847 - mean_absolute_error: 465.3847 - val_loss: 2579.7456 - val_mean_absolute_error: 2579.7456
# Epoch 127/500
# 1/4 [======>.......................] - ETA: 0s - loss: 312.2538 - mean_absolute_error: 312.2538
# Epoch 127: val_loss improved from 2572.08325 to 2567.21362, saving model to Weights-127--2567.21362.hdf5
# 4/4 [==============================] - 0s 20ms/step - loss: 491.1952 - mean_absolute_error: 491.1952 - val_loss: 2567.2136 - val_mean_absolute_error: 2567.2136
# Epoch 128/500
# 1/4 [======>.......................] - ETA: 0s - loss: 489.7040 - mean_absolute_error: 489.7040
# Epoch 128: val_loss did not improve from 2567.21362
# 4/4 [==============================] - 0s 12ms/step - loss: 464.3513 - mean_absolute_error: 464.3513 - val_loss: 2583.5400 - val_mean_absolute_error: 2583.5400
# Epoch 129/500
# 1/4 [======>.......................] - ETA: 0s - loss: 781.3721 - mean_absolute_error: 781.3721
# Epoch 129: val_loss did not improve from 2567.21362
# 4/4 [==============================] - 0s 11ms/step - loss: 460.5613 - mean_absolute_error: 460.5613 - val_loss: 2574.5315 - val_mean_absolute_error: 2574.5315
# Epoch 130/500
# 1/4 [======>.......................] - ETA: 0s - loss: 548.6840 - mean_absolute_error: 548.6840
# Epoch 130: val_loss did not improve from 2567.21362
# 4/4 [==============================] - 0s 13ms/step - loss: 446.8148 - mean_absolute_error: 446.8148 - val_loss: 2593.1274 - val_mean_absolute_error: 2593.1274
# Epoch 131/500
# 1/4 [======>.......................] - ETA: 0s - loss: 335.1581 - mean_absolute_error: 335.1581
# Epoch 131: val_loss did not improve from 2567.21362
# 4/4 [==============================] - 0s 12ms/step - loss: 433.9099 - mean_absolute_error: 433.9099 - val_loss: 2589.4954 - val_mean_absolute_error: 2589.4954
# Epoch 132/500
# 1/4 [======>.......................] - ETA: 0s - loss: 159.9460 - mean_absolute_error: 159.9460
# Epoch 132: val_loss did not improve from 2567.21362
# 4/4 [==============================] - 0s 12ms/step - loss: 437.2255 - mean_absolute_error: 437.2255 - val_loss: 2591.3521 - val_mean_absolute_error: 2591.3521
# Epoch 133/500
# 1/4 [======>.......................] - ETA: 0s - loss: 497.7125 - mean_absolute_error: 497.7125
# Epoch 133: val_loss did not improve from 2567.21362
# 4/4 [==============================] - 0s 12ms/step - loss: 454.3903 - mean_absolute_error: 454.3903 - val_loss: 2588.9792 - val_mean_absolute_error: 2588.9792
# Epoch 134/500
# 1/4 [======>.......................] - ETA: 0s - loss: 416.8434 - mean_absolute_error: 416.8434
# Epoch 134: val_loss did not improve from 2567.21362
# 4/4 [==============================] - 0s 11ms/step - loss: 443.9529 - mean_absolute_error: 443.9529 - val_loss: 2601.2075 - val_mean_absolute_error: 2601.2075
# Epoch 135/500
# 1/4 [======>.......................] - ETA: 0s - loss: 678.1995 - mean_absolute_error: 678.1995
# Epoch 135: val_loss did not improve from 2567.21362
# 4/4 [==============================] - 0s 13ms/step - loss: 443.8451 - mean_absolute_error: 443.8451 - val_loss: 2587.4844 - val_mean_absolute_error: 2587.4844
# Epoch 136/500
# 1/4 [======>.......................] - ETA: 0s - loss: 711.3329 - mean_absolute_error: 711.3329
# Epoch 136: val_loss did not improve from 2567.21362
# 4/4 [==============================] - 0s 13ms/step - loss: 444.9402 - mean_absolute_error: 444.9402 - val_loss: 2583.6978 - val_mean_absolute_error: 2583.6978
# ...
# Epoch 453/500
# 1/4 [======>.......................] - ETA: 0s - loss: 285.6632 - mean_absolute_error: 285.6632
# Epoch 453: val_loss improved from 2166.25879 to 2162.13452, saving model to Weights-453--2162.13452.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 253.4769 - mean_absolute_error: 253.4769 - val_loss: 2162.1345 - val_mean_absolute_error: 2162.1345
# Epoch 454/500
# 1/4 [======>.......................] - ETA: 0s - loss: 168.7356 - mean_absolute_error: 168.7356
# Epoch 454: val_loss improved from 2162.13452 to 2150.34692, saving model to Weights-454--2150.34692.hdf5
# 4/4 [==============================] - 0s 25ms/step - loss: 258.1440 - mean_absolute_error: 258.1440 - val_loss: 2150.3469 - val_mean_absolute_error: 2150.3469
# Epoch 455/500
# 1/4 [======>.......................] - ETA: 0s - loss: 328.8047 - mean_absolute_error: 328.8047
# Epoch 455: val_loss did not improve from 2150.34692
# 4/4 [==============================] - 0s 15ms/step - loss: 263.7487 - mean_absolute_error: 263.7487 - val_loss: 2159.8667 - val_mean_absolute_error: 2159.8667
# Epoch 456/500
# 1/4 [======>.......................] - ETA: 0s - loss: 188.5276 - mean_absolute_error: 188.5276
# Epoch 456: val_loss did not improve from 2150.34692
# 4/4 [==============================] - 0s 16ms/step - loss: 271.1544 - mean_absolute_error: 271.1544 - val_loss: 2179.2949 - val_mean_absolute_error: 2179.2949
# Epoch 457/500
# 1/4 [======>.......................] - ETA: 0s - loss: 56.7581 - mean_absolute_error: 56.7581
# Epoch 457: val_loss did not improve from 2150.34692
# 4/4 [==============================] - 0s 16ms/step - loss: 271.1693 - mean_absolute_error: 271.1693 - val_loss: 2179.6592 - val_mean_absolute_error: 2179.6592
# Epoch 458/500
# 1/4 [======>.......................] - ETA: 0s - loss: 422.3183 - mean_absolute_error: 422.3183
# Epoch 458: val_loss did not improve from 2150.34692
# 4/4 [==============================] - 0s 21ms/step - loss: 273.8862 - mean_absolute_error: 273.8862 - val_loss: 2166.9417 - val_mean_absolute_error: 2166.9417
# Epoch 459/500
# 1/4 [======>.......................] - ETA: 0s - loss: 296.3960 - mean_absolute_error: 296.3960
# Epoch 459: val_loss did not improve from 2150.34692
# 4/4 [==============================] - 0s 14ms/step - loss: 280.0198 - mean_absolute_error: 280.0198 - val_loss: 2182.4924 - val_mean_absolute_error: 2182.4924
# Epoch 460/500
# 1/4 [======>.......................] - ETA: 0s - loss: 393.6224 - mean_absolute_error: 393.6224
# Epoch 460: val_loss did not improve from 2150.34692
# 4/4 [==============================] - 0s 14ms/step - loss: 262.9585 - mean_absolute_error: 262.9585 - val_loss: 2171.4045 - val_mean_absolute_error: 2171.4045
# Epoch 461/500
# 1/4 [======>.......................] - ETA: 0s - loss: 512.9209 - mean_absolute_error: 512.9209
# Epoch 461: val_loss did not improve from 2150.34692
# 4/4 [==============================] - 0s 15ms/step - loss: 260.6615 - mean_absolute_error: 260.6615 - val_loss: 2161.3062 - val_mean_absolute_error: 2161.3062
# Epoch 462/500
# 1/4 [======>.......................] - ETA: 0s - loss: 183.0215 - mean_absolute_error: 183.0215
# Epoch 462: val_loss did not improve from 2150.34692
# 4/4 [==============================] - 0s 14ms/step - loss: 259.8926 - mean_absolute_error: 259.8926 - val_loss: 2180.5046 - val_mean_absolute_error: 2180.5046
# Epoch 463/500
# 1/4 [======>.......................] - ETA: 0s - loss: 235.4843 - mean_absolute_error: 235.4843
# Epoch 463: val_loss did not improve from 2150.34692
# 4/4 [==============================] - 0s 14ms/step - loss: 249.3935 - mean_absolute_error: 249.3935 - val_loss: 2171.5500 - val_mean_absolute_error: 2171.5500
# Epoch 464/500
# 1/4 [======>.......................] - ETA: 0s - loss: 256.7094 - mean_absolute_error: 256.7094
# Epoch 464: val_loss did not improve from 2150.34692
# 4/4 [==============================] - 0s 16ms/step - loss: 259.5822 - mean_absolute_error: 259.5822 - val_loss: 2172.3669 - val_mean_absolute_error: 2172.3669
# Epoch 465/500
# 1/4 [======>.......................] - ETA: 0s - loss: 167.0307 - mean_absolute_error: 167.0307
# Epoch 465: val_loss did not improve from 2150.34692
# 4/4 [==============================] - 0s 20ms/step - loss: 276.5060 - mean_absolute_error: 276.5060 - val_loss: 2167.1721 - val_mean_absolute_error: 2167.1721
# Epoch 466/500
# 1/4 [======>.......................] - ETA: 0s - loss: 95.6605 - mean_absolute_error: 95.6605
# Epoch 466: val_loss improved from 2150.34692 to 2144.93335, saving model to Weights-466--2144.93335.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 258.9403 - mean_absolute_error: 258.9403 - val_loss: 2144.9333 - val_mean_absolute_error: 2144.9333
# Epoch 467/500
# 1/4 [======>.......................] - ETA: 0s - loss: 481.2561 - mean_absolute_error: 481.2561
# Epoch 467: val_loss did not improve from 2144.93335
# 4/4 [==============================] - 0s 19ms/step - loss: 270.3509 - mean_absolute_error: 270.3509 - val_loss: 2154.6848 - val_mean_absolute_error: 2154.6848
# Epoch 468/500
# 1/4 [======>.......................] - ETA: 0s - loss: 177.3338 - mean_absolute_error: 177.3338
# Epoch 468: val_loss did not improve from 2144.93335
# 4/4 [==============================] - 0s 14ms/step - loss: 258.7688 - mean_absolute_error: 258.7688 - val_loss: 2160.4956 - val_mean_absolute_error: 2160.4956
# Epoch 469/500
# 1/4 [======>.......................] - ETA: 0s - loss: 363.0592 - mean_absolute_error: 363.0592
# Epoch 469: val_loss did not improve from 2144.93335
# 4/4 [==============================] - 0s 14ms/step - loss: 255.2124 - mean_absolute_error: 255.2124 - val_loss: 2154.8911 - val_mean_absolute_error: 2154.8911
# Epoch 470/500
# 1/4 [======>.......................] - ETA: 0s - loss: 373.1298 - mean_absolute_error: 373.1298
# Epoch 470: val_loss did not improve from 2144.93335
# 4/4 [==============================] - 0s 16ms/step - loss: 248.0374 - mean_absolute_error: 248.0374 - val_loss: 2155.8328 - val_mean_absolute_error: 2155.8328
# Epoch 471/500
# 1/4 [======>.......................] - ETA: 0s - loss: 315.1155 - mean_absolute_error: 315.1155
# Epoch 471: val_loss did not improve from 2144.93335
# 4/4 [==============================] - 0s 15ms/step - loss: 246.9726 - mean_absolute_error: 246.9726 - val_loss: 2160.0344 - val_mean_absolute_error: 2160.0344
# Epoch 472/500
# 1/4 [======>.......................] - ETA: 0s - loss: 198.7167 - mean_absolute_error: 198.7167
# Epoch 472: val_loss improved from 2144.93335 to 2138.49048, saving model to Weights-472--2138.49048.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 245.4317 - mean_absolute_error: 245.4317 - val_loss: 2138.4905 - val_mean_absolute_error: 2138.4905
# Epoch 473/500
# 1/4 [======>.......................] - ETA: 0s - loss: 315.5530 - mean_absolute_error: 315.5530
# Epoch 473: val_loss improved from 2138.49048 to 2127.50586, saving model to Weights-473--2127.50586.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 260.9686 - mean_absolute_error: 260.9686 - val_loss: 2127.5059 - val_mean_absolute_error: 2127.5059
# Epoch 474/500
# 1/4 [======>.......................] - ETA: 0s - loss: 185.2509 - mean_absolute_error: 185.2509
# Epoch 474: val_loss did not improve from 2127.50586
# 4/4 [==============================] - 0s 13ms/step - loss: 258.4958 - mean_absolute_error: 258.4958 - val_loss: 2140.6621 - val_mean_absolute_error: 2140.6621
# Epoch 475/500
# 1/4 [======>.......................] - ETA: 0s - loss: 268.9794 - mean_absolute_error: 268.9794
# Epoch 475: val_loss did not improve from 2127.50586
# 4/4 [==============================] - 0s 15ms/step - loss: 262.4525 - mean_absolute_error: 262.4525 - val_loss: 2136.6035 - val_mean_absolute_error: 2136.6035
# Epoch 476/500
# 1/4 [======>.......................] - ETA: 0s - loss: 158.1362 - mean_absolute_error: 158.1362
# Epoch 476: val_loss improved from 2127.50586 to 2124.36377, saving model to Weights-476--2124.36377.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 257.9917 - mean_absolute_error: 257.9917 - val_loss: 2124.3638 - val_mean_absolute_error: 2124.3638
# Epoch 477/500
# 1/4 [======>.......................] - ETA: 0s - loss: 225.6851 - mean_absolute_error: 225.6851
# Epoch 477: val_loss did not improve from 2124.36377
# 4/4 [==============================] - 0s 15ms/step - loss: 264.5230 - mean_absolute_error: 264.5230 - val_loss: 2143.3279 - val_mean_absolute_error: 2143.3279
# Epoch 478/500
# 1/4 [======>.......................] - ETA: 0s - loss: 399.4005 - mean_absolute_error: 399.4005
# Epoch 478: val_loss did not improve from 2124.36377
# 4/4 [==============================] - 0s 14ms/step - loss: 260.7690 - mean_absolute_error: 260.7690 - val_loss: 2149.2207 - val_mean_absolute_error: 2149.2207
# Epoch 479/500
# 1/4 [======>.......................] - ETA: 0s - loss: 368.6483 - mean_absolute_error: 368.6483
# Epoch 479: val_loss did not improve from 2124.36377
# 4/4 [==============================] - 0s 21ms/step - loss: 268.9058 - mean_absolute_error: 268.9058 - val_loss: 2147.5671 - val_mean_absolute_error: 2147.5671
# Epoch 480/500
# 1/4 [======>.......................] - ETA: 0s - loss: 178.9439 - mean_absolute_error: 178.9439
# Epoch 480: val_loss did not improve from 2124.36377
# 4/4 [==============================] - 0s 15ms/step - loss: 272.6647 - mean_absolute_error: 272.6647 - val_loss: 2159.6934 - val_mean_absolute_error: 2159.6934
# Epoch 481/500
# 1/4 [======>.......................] - ETA: 0s - loss: 193.2828 - mean_absolute_error: 193.2828
# Epoch 481: val_loss did not improve from 2124.36377
# 4/4 [==============================] - 0s 15ms/step - loss: 294.6149 - mean_absolute_error: 294.6149 - val_loss: 2136.1516 - val_mean_absolute_error: 2136.1516
# Epoch 482/500
# 1/4 [======>.......................] - ETA: 0s - loss: 341.8592 - mean_absolute_error: 341.8592
# Epoch 482: val_loss did not improve from 2124.36377
# 4/4 [==============================] - 0s 14ms/step - loss: 297.0156 - mean_absolute_error: 297.0156 - val_loss: 2134.1516 - val_mean_absolute_error: 2134.1516
# Epoch 483/500
# 1/4 [======>.......................] - ETA: 0s - loss: 168.7446 - mean_absolute_error: 168.7446
# Epoch 483: val_loss did not improve from 2124.36377
# 4/4 [==============================] - 0s 14ms/step - loss: 269.5323 - mean_absolute_error: 269.5323 - val_loss: 2148.8342 - val_mean_absolute_error: 2148.8342
# Epoch 484/500
# 1/4 [======>.......................] - ETA: 0s - loss: 363.4991 - mean_absolute_error: 363.4991
# Epoch 484: val_loss did not improve from 2124.36377
# 4/4 [==============================] - 0s 16ms/step - loss: 275.8326 - mean_absolute_error: 275.8326 - val_loss: 2133.4016 - val_mean_absolute_error: 2133.4016
# Epoch 485/500
# 1/4 [======>.......................] - ETA: 0s - loss: 282.5391 - mean_absolute_error: 282.5391
# Epoch 485: val_loss improved from 2124.36377 to 2120.43237, saving model to Weights-485--2120.43237.hdf5
# 4/4 [==============================] - 0s 30ms/step - loss: 273.0106 - mean_absolute_error: 273.0106 - val_loss: 2120.4324 - val_mean_absolute_error: 2120.4324
# Epoch 486/500
# 1/4 [======>.......................] - ETA: 0s - loss: 177.9810 - mean_absolute_error: 177.9810
# Epoch 486: val_loss did not improve from 2120.43237
# 4/4 [==============================] - 0s 15ms/step - loss: 255.8853 - mean_absolute_error: 255.8853 - val_loss: 2142.7561 - val_mean_absolute_error: 2142.7561
# Epoch 487/500
# 1/4 [======>.......................] - ETA: 0s - loss: 330.2431 - mean_absolute_error: 330.2431
# Epoch 487: val_loss did not improve from 2120.43237
# 4/4 [==============================] - 0s 15ms/step - loss: 261.0480 - mean_absolute_error: 261.0480 - val_loss: 2126.9417 - val_mean_absolute_error: 2126.9417
# Epoch 488/500
# 1/4 [======>.......................] - ETA: 0s - loss: 358.4238 - mean_absolute_error: 358.4238
# Epoch 488: val_loss did not improve from 2120.43237
# 4/4 [==============================] - 0s 14ms/step - loss: 277.9710 - mean_absolute_error: 277.9710 - val_loss: 2128.7832 - val_mean_absolute_error: 2128.7832
# Epoch 489/500
# 1/4 [======>.......................] - ETA: 0s - loss: 295.8378 - mean_absolute_error: 295.8378
# Epoch 489: val_loss did not improve from 2120.43237
# 4/4 [==============================] - 0s 14ms/step - loss: 267.6539 - mean_absolute_error: 267.6539 - val_loss: 2134.6240 - val_mean_absolute_error: 2134.6240
# Epoch 490/500
# 1/4 [======>.......................] - ETA: 0s - loss: 113.1332 - mean_absolute_error: 113.1332
# Epoch 490: val_loss did not improve from 2120.43237
# 4/4 [==============================] - 0s 14ms/step - loss: 268.1445 - mean_absolute_error: 268.1445 - val_loss: 2125.0120 - val_mean_absolute_error: 2125.0120
# Epoch 491/500
# 1/4 [======>.......................] - ETA: 0s - loss: 215.9132 - mean_absolute_error: 215.9132
# Epoch 491: val_loss did not improve from 2120.43237
# 4/4 [==============================] - 0s 16ms/step - loss: 268.3736 - mean_absolute_error: 268.3736 - val_loss: 2124.4775 - val_mean_absolute_error: 2124.4775
# Epoch 492/500
# 1/4 [======>.......................] - ETA: 0s - loss: 229.8012 - mean_absolute_error: 229.8012
# Epoch 492: val_loss did not improve from 2120.43237
# 4/4 [==============================] - 0s 15ms/step - loss: 268.0772 - mean_absolute_error: 268.0772 - val_loss: 2122.8301 - val_mean_absolute_error: 2122.8301
# Epoch 493/500
# 1/4 [======>.......................] - ETA: 0s - loss: 289.8021 - mean_absolute_error: 289.8021
# Epoch 493: val_loss did not improve from 2120.43237
# 4/4 [==============================] - 0s 16ms/step - loss: 275.7205 - mean_absolute_error: 275.7205 - val_loss: 2120.9875 - val_mean_absolute_error: 2120.9875
# Epoch 494/500
# 1/4 [======>.......................] - ETA: 0s - loss: 278.6614 - mean_absolute_error: 278.6614
# Epoch 494: val_loss did not improve from 2120.43237
# 4/4 [==============================] - 0s 15ms/step - loss: 255.6026 - mean_absolute_error: 255.6026 - val_loss: 2128.2727 - val_mean_absolute_error: 2128.2727
# Epoch 495/500
# 1/4 [======>.......................] - ETA: 0s - loss: 197.9167 - mean_absolute_error: 197.9167
# Epoch 495: val_loss did not improve from 2120.43237
# 4/4 [==============================] - 0s 14ms/step - loss: 259.0706 - mean_absolute_error: 259.0706 - val_loss: 2136.0671 - val_mean_absolute_error: 2136.0671
# Epoch 496/500
# 1/4 [======>.......................] - ETA: 0s - loss: 304.5548 - mean_absolute_error: 304.5548
# Epoch 496: val_loss improved from 2120.43237 to 2108.07324, saving model to Weights-496--2108.07324.hdf5
# 4/4 [==============================] - 0s 22ms/step - loss: 263.2703 - mean_absolute_error: 263.2703 - val_loss: 2108.0732 - val_mean_absolute_error: 2108.0732
# Epoch 497/500
# 1/4 [======>.......................] - ETA: 0s - loss: 236.7594 - mean_absolute_error: 236.7594
# Epoch 497: val_loss did not improve from 2108.07324
# 4/4 [==============================] - 0s 16ms/step - loss: 261.4031 - mean_absolute_error: 261.4031 - val_loss: 2113.5991 - val_mean_absolute_error: 2113.5991
# Epoch 498/500
# 1/4 [======>.......................] - ETA: 0s - loss: 354.7479 - mean_absolute_error: 354.7479
# Epoch 498: val_loss did not improve from 2108.07324
# 4/4 [==============================] - 0s 14ms/step - loss: 275.8028 - mean_absolute_error: 275.8028 - val_loss: 2134.9087 - val_mean_absolute_error: 2134.9087
# Epoch 499/500
# 1/4 [======>.......................] - ETA: 0s - loss: 179.2176 - mean_absolute_error: 179.2176
# Epoch 499: val_loss did not improve from 2108.07324
# 4/4 [==============================] - 0s 14ms/step - loss: 283.7060 - mean_absolute_error: 283.7060 - val_loss: 2136.5398 - val_mean_absolute_error: 2136.5398
# Epoch 500/500
# 1/4 [======>.......................] - ETA: 0s - loss: 134.8804 - mean_absolute_error: 134.8804
# Epoch 500: val_loss did not improve from 2108.07324
# 4/4 [==============================] - 0s 13ms/step - loss: 286.8507 - mean_absolute_error: 286.8507 - val_loss: 2121.5854 - val_mean_absolute_error: 2121.5854

# %%
y_pred5 = NNmodel.predict(X_test)
print_metrics(Y_test,y_pred5)
# Out:
# 2/2 [==============================] - 0s 6ms/step
# Mean Absolute Error: 1919.13
# Mean Squared Error: 6218936.12
# Root Mean Squared Error: 2493.78
# Mean Absolute Percentage Error: 0.15
# R2 score: 0.93

# %% [markdown]
# ### Conclusions
# 1. This problem statement was identified as Regression problem.
# 2. Used several regression models to predict the price of the cars with least error.
# 3. The Multiple Linear Regression, Decision Tree Regression, Random Forest Regression and XGBRegression performs very well on the training as well as test sets with Model scores of `92.75%`, `88.2%`, `93.78%` and `92.45%` respectively.
# 4. Among all models the Random Forest Regression technique performs best, but the difference is not much. Any of the three models can be used by the company.
# 5. We also tried regression using Sequential Neural Networks, produced output has a `Root mean square error` value of `2391.99` and `R2 score` of `0.93` which is also a good score.

# %%
plt.figure(figsize=(18,8), dpi = 300)
plt.suptitle("Performance of models on training data", fontsize = 20)
plt.subplot(2,3,1)
plt.plot(Y_test,Y_test)
plt.scatter(Y_test,y_pred1, color = 'r', label = 'Linear Regression Model')
plt.xlabel('Price')
plt.legend()

plt.subplot(2,3,2)
plt.plot(Y_test,Y_test)
plt.scatter(Y_test,y_pred2, color = 'g', label = 'Decision Tree Regression Model')
plt.xlabel('Price')
plt.legend()

plt.subplot(2,3,3)
plt.plot(Y_test,Y_test)
plt.scatter(Y_test,y_pred3, color = 'b', label = 'Random Forest Regression Model')
plt.xlabel('Price')
plt.legend()

plt.subplot(2,3,4)
plt.plot(Y_test,Y_test)
plt.scatter(Y_test,y_pred4, color = 'y', label = 'XGBooster Regression Model')
plt.xlabel('Price')
plt.legend()

plt.subplot(2,3,5)
plt.plot(Y_test,Y_test)
plt.scatter(Y_test,y_pred5, color = 'violet', label = 'Neural Network based Regression Model')
plt.xlabel('Price')
plt.legend()

plt.show()
